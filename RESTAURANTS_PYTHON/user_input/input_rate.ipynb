# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display

# %%
# this section will be inactive in final application
df = pd.read_csv('zomato_clean.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12066 entries, 0 to 12065
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        12066 non-null  object
#  1   address    12066 non-null  object
#  2   name       12066 non-null  object
#  3   rate       9061 non-null   float64
#  4   votes      12066 non-null  int64
#  5   phone      12066 non-null  object
#  6   location   12066 non-null  object
#  7   rest_type  12010 non-null  object
#  8   cuisines   12066 non-null  object
#  9   cost       12019 non-null  float64
#  10  latitude   12066 non-null  float64
#  11  longitude  12066 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
slider = widgets.FloatSlider(
    value=4,
    min=0,
    max=5,
    description='Min. rate:',
    readout_format='.1f'
    )

slider
# Out:
# FloatSlider(value=4.0, description='Min. rate:', max=5.0, readout_format='.1f')

# %%
slider.value
# Out:
# 4.5

# %%
def filter_dataframe(dataset, rate):
    df.query(f'rate >= {rate}', inplace=True)
    return df

# %%
filter_dataframe(df, slider.value)
# Out:
#                                                      url  \
# 7      https://www.zomato.com/bangalore/onesta-banash...
# 160    https://www.zomato.com/bangalore/the-blue-wago...
# 177    https://www.zomato.com/bangalore/shakes-theory...
# 504    https://www.zomato.com/bangalore/taaza-thindi-...
# 598    https://www.zomato.com/bangalore/barbeque-nati...
# ...                                                  ...
# 11709  https://www.zomato.com/bangalore/maziga-whitef...
# 11925  https://www.zomato.com/bangalore/belgyum-white...
# 11947  https://www.zomato.com/bangalore/feast-sherato...
# 11948  https://www.zomato.com/bangalore/the-pallet-wh...
# 12056  https://www.zomato.com/bangalore/chianti-white...
#
#                                                  address  \
# 7      2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
# 160    615/1, Ground Floor, Janardhan Mansion, 10th C...
# 177    766/25-01, 47th A Cross, Near Sangam Circle, A...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 7 to 12056
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   url        186 non-null    object
#  1   address    186 non-null    object
#  2   name       186 non-null    object
#  3   rate       186 non-null    float64
#  4   votes      186 non-null    int64
#  5   phone      186 non-null    object
#  6   location   186 non-null    object
#  7   rest_type  186 non-null    object
#  8   cuisines   186 non-null    object
#  9   cost       186 non-null    float64
#  10  latitude   186 non-null    float64
#  11  longitude  186 non-null    float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 18.9+ KB
